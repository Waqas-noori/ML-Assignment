# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Waqas-noori/ML-Assignment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Ranking Signal Analysis
#
# I already explored this in notebooks 01 & 02, checking if search volume
# predicts impressions, if CTR drops by position, and if word count matters.
# I want to keep going down that path: find which signals actually relate
# to visibility and clicks, using real data instead of guesses. A model helps
# here because it can weigh several weak signals together, something a
# single hand-picked rule can't do well.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: which signals a content team should actually pay attention to
# when writing or updating pages.
#
# Action: a writer/editor adjusts things like title, position targeting,
# or update frequency based on what's shown to matter.
#
# Cost of a wrong call: if I flag a signal as important when it isn't,
# the team wastes effort on the wrong fix. If I miss a real signal,
# they keep ignoring something that actually helps.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os

if not os.path.exists("/content/ML-Assignment"):
    # !git clone https://github.com/Waqas-noori/ML-Assignment.git

import pandas as pd

df = pd.read_csv("/content/ML-Assignment/data/raw/content_refresh_anonymized.csv")

# Number 1: does search volume predict impressions?
corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation between search_volume and impressions_90d: {corr:.3f}")

# Number 2: does CTR drop as position tier gets worse?
ctr_by_tier = df.groupby("position_tier")["ctr"].mean()
print("Average CTR by position tier:")
print(ctr_by_tier.round(3))
# Out:
# Correlation between search_volume and impressions_90d: 0.001
# Average CTR by position tier:
# position_tier
# deep        0.150
# page_1      0.652
# page_3_5    0.222
# striking    0.323
# top_3       1.484
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work CAN say: which signals are associated with visibility or clicks,
# based on patterns observed in this dataset.
#
# This work CANNOT say: that any signal causes higher rankings, or that
# this reflects how Google's algorithm actually works. It's observation,
# not proof.

# %% [markdown]
# This work CAN say: which signals are associated with visibility or clicks,
# based on patterns observed in this dataset.
#
# This work CANNOT say: that any signal causes higher rankings, or that
# this reflects how Google's algorithm actually works. It's observation,
# not proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
